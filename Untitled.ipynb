# %%
from biolearn.data_library import DataLibrary

data = DataLibrary().get("GSE180683").load()

data.dnam
# Out:
# Empty DataFrame
# Columns: [GSM5467948, GSM5467949, GSM5467950, GSM5467951, GSM5467952, GSM5467953, GSM5467954, GSM5467955, GSM5467956, GSM5467957, GSM5467958, GSM5467959, GSM5467960, GSM5467961, GSM5467962, GSM5467963, GSM5467964, GSM5467965, GSM5467966, GSM5467967, GSM5467968, GSM5467969, GSM5467970, GSM5467971, GSM5467972, GSM5467973, GSM5467974, GSM5467975, GSM5467976, GSM5467977, GSM5467978, GSM5467979, GSM5467980, GSM5467981, GSM5467982, GSM5467983, GSM5467984, GSM5467985, GSM5467986, GSM5467987, GSM5467988, GSM5467989, GSM5467990, GSM5467991, GSM5467992, GSM5467993, GSM5467994, GSM5467995, GSM5467996, GSM5467997, GSM5467998, GSM5467999, GSM5468000, GSM5468001, GSM5468002, GSM5468003, GSM5468004, GSM5468005, GSM5468006, GSM5468007, GSM5468008, GSM5468009, GSM5468010, GSM5468011, GSM5468012, GSM5468013, GSM5468014, GSM5468015, GSM5468016, GSM5468017, GSM5468018, GSM5468019, GSM5468020, GSM5468021, GSM5468022, GSM5468023]
# Index: []
#
# [0 rows x 76 columns]

# %%
from biolearn.cache import NoCache

data = DataLibrary(cache=NoCache()).get("GSE180683").load()

data.dnam
# Out:
# Note: This dataset will take a few minutes to load and may fail if you have insufficient memory
# /Users/chancenlaw/Desktop/Biolearn/biolearn/biolearn/data_library.py:345: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(
#                 GSM5468023  GSM5468022  GSM5468021  GSM5468020  GSM5468019  \
# ID_REF
# cg00000029        0.726959         NaN    0.626813    0.750695    0.640784
# cg00000103        0.949141    0.952060    0.941584    0.948519    0.944630
# cg00000109        0.946190    0.936612    0.933314    0.944472    0.937785
# cg00000155        0.960865    0.964887    0.960467    0.957448    0.959806
# cg00000158        0.966785    0.966120    0.960736    0.960002    0.964695
# ...                    ...         ...         ...         ...         ...
# ...

# %%
import pandas as pd
matrix_file_path = "https://ftp.ncbi.nlm.nih.gov/geo/series/GSE180nnn/GSE180683/suppl/GSE180683%5FMatrix%5Fprocessed%2Etxt%2Egz"
df = pd.read_csv(matrix_file_path, index_col=0, sep="\t")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[13], line 3
#       1 import pandas as pd
#       2 matrix_file_path = "https://ftp.ncbi.nlm.nih.gov/geo/series/GSE180nnn/GSE180683/suppl/GSE180683%5FMatrix%5Fprocessed%2Etxt%2Egz"
# ----> 3 df = pd.read_csv(matrix_file_path, index_col=0, sep="\t")
#
# ...
